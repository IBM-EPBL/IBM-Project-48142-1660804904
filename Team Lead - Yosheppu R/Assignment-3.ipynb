# %%
#IMPORTING THE libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
#importing the dataset
df=pd.read_csv(r"E:\Assignment-3\abalone.csv")

# %%
#PERFORM VISUALIZATION
#univariate analysis
df.nunique()

# %%
#univariate analysis
df.head()

# %%
#Bi-variate analysis
sns.FacetGrid(df,hue="Rings",size=5)
plt.show()
# Out:
# C:\Users\D.K\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#multi-variate analysis
sns.pairplot(df, hue="Rings", height=2)

# %%
#DESCRIPTION STATICS ON THE DATASET
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
#missing values
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
#CHECKS FOR THE CATEGORICAL COLUMNS AND PERFORM ENCODING
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
#SPLIT THE DATA INTO DEPENDENT AND INDEPENDENT VARIABLES
x = df.iloc[:,1].values
print(x)
# Out:
# [0.455 0.35  0.53  ... 0.6   0.625 0.71 ]

# %%
#Extracting the Dataset to Get the Dependent variable
y = df.iloc[:,1].values
print(y)
# Out:
# [0.455 0.35  0.53  ... 0.6   0.625 0.71 ]

# %%
#SCALE THE INDEPENDENT VARIABLES
# Initialise the Scaler
scaler = StandardScaler()

# %%
#SPLIT THE DATA INTO TRAINING AND TESTING
from sklearn.model_selection import train_test_split
df = pd.read_csv(r"E:\Assignment-3\abalone.csv")
x= df.iloc[:,1].values
y=df.iloc[:,1].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.05, random_state=0)

# %%
print (x_train)
# Out:
# [0.45  0.255 0.575 ... 0.595 0.625 0.41 ]

# %%
print(y_train)
# Out:
# [0.45  0.255 0.575 ... 0.595 0.625 0.41 ]

# %%
print(x_test)
# Out:
# [0.55  0.5   0.62  0.22  0.645 0.65  0.465 0.485 0.405 0.62  0.475 0.295
#  0.41  0.505 0.23  0.58  0.35  0.565 0.61  0.465 0.39  0.365 0.46  0.345
#  0.56  0.56  0.155 0.635 0.57  0.535 0.38  0.16  0.585 0.735 0.44  0.515
#  0.475 0.615 0.435 0.635 0.565 0.49  0.52  0.535 0.6   0.465 0.61  0.67
#  0.535 0.415 0.585 0.395 0.435 0.595 0.505 0.47  0.255 0.34  0.41  0.375
#  0.615 0.62  0.585 0.49  0.405 0.65  0.7   0.645 0.54  0.675 0.525 0.73
#  0.63  0.585 0.59  0.5   0.58  0.525 0.61  0.49  0.62  0.28  0.405 0.575
#  0.56  0.475 0.61  0.645 0.175 0.37  0.58  0.565 0.46  0.355 0.535 0.29
#  0.52  0.37  0.52  0.72  0.615 0.47  0.68  0.625 0.215 0.64  0.5   0.365
#  0.355 0.615 0.72  0.71  0.5   0.575 0.58  0.715 0.655 0.59  0.28  0.535
#  0.365 0.545 0.375 0.475 0.575 0.62  0.605 0.675 0.415 0.635 0.615 0.475
#  0.505 0.65  0.68  0.62  0.51  0.515 0.375 0.65  0.465 0.455 0.35  0.57
#  0.59  0.565 0.46  0.495 0.48  0.32  0.495 0.68  0.385 0.635 0.34  0.37
# ...

# %%
print(y_test)
# Out:
# [0.55  0.5   0.62  0.22  0.645 0.65  0.465 0.485 0.405 0.62  0.475 0.295
#  0.41  0.505 0.23  0.58  0.35  0.565 0.61  0.465 0.39  0.365 0.46  0.345
#  0.56  0.56  0.155 0.635 0.57  0.535 0.38  0.16  0.585 0.735 0.44  0.515
#  0.475 0.615 0.435 0.635 0.565 0.49  0.52  0.535 0.6   0.465 0.61  0.67
#  0.535 0.415 0.585 0.395 0.435 0.595 0.505 0.47  0.255 0.34  0.41  0.375
#  0.615 0.62  0.585 0.49  0.405 0.65  0.7   0.645 0.54  0.675 0.525 0.73
#  0.63  0.585 0.59  0.5   0.58  0.525 0.61  0.49  0.62  0.28  0.405 0.575
#  0.56  0.475 0.61  0.645 0.175 0.37  0.58  0.565 0.46  0.355 0.535 0.29
#  0.52  0.37  0.52  0.72  0.615 0.47  0.68  0.625 0.215 0.64  0.5   0.365
#  0.355 0.615 0.72  0.71  0.5   0.575 0.58  0.715 0.655 0.59  0.28  0.535
#  0.365 0.545 0.375 0.475 0.575 0.62  0.605 0.675 0.415 0.635 0.615 0.475
#  0.505 0.65  0.68  0.62  0.51  0.515 0.375 0.65  0.465 0.455 0.35  0.57
#  0.59  0.565 0.46  0.495 0.48  0.32  0.495 0.68  0.385 0.635 0.34  0.37
# ...
